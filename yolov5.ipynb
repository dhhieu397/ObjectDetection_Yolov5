# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v6.1-223-g1dcb774 Python-3.7.13 torch-1.11.0+cu113 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 38.4/107.7 GB disk)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pwd
# Out:
# /content/yolov5

# %%
# !cd '/content/yolov5'

# %%
# !cd '/content/yolov5/' && python detect.py --source /content/drive/MyDrive/ObjectDetection_Yolov5/giaothong.jpeg
# Out:
# detect: weights=yolov5s.pt, source=/content/drive/MyDrive/ObjectDetection_Yolov5/giaothong.jpeg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-223-g1dcb774 Python-3.7.13 torch-1.11.0+cu113 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# image 1/1 /content/drive/MyDrive/ObjectDetection_Yolov5/giaothong.jpeg: 416x640 4 persons, 3 cars, 5 motorcycles, 1 bus, 4 trucks, Done. (0.313s)
# Speed: 3.7ms pre-process, 313.0ms inference, 14.9ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp4

# %%
# !cd '/content/yolov5/' && python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source /content/yolov5/data/images
# Out:
# detect: weights=['yolov5s.pt'], source=/content/yolov5/data/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-223-g1dcb774 Python-3.7.13 torch-1.11.0+cu113 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# image 1/2 /content/yolov5/data/images/bus.jpg: 640x480 4 persons, 1 bus, Done. (0.343s)
# image 2/2 /content/yolov5/data/images/zidane.jpg: 384x640 2 persons, 2 ties, Done. (0.264s)
# Speed: 2.5ms pre-process, 303.3ms inference, 1.2ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp5

# %%
# !pwd
# Out:
# /content/drive/MyDrive/ObjectDetection_Yolov5

# %%
display.Image(filename='/content/yolov5/runs/detect/exp5/zidane.jpg', width=600)

# %%
display.Image(filename='/content/yolov5/runs/detect/exp5/bus.jpg', width=600)

# %%
display.Image(filename='/content/yolov5/runs/detect/exp4/giaothong.jpeg', width=600)
